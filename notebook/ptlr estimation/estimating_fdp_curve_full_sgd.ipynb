# %%
import os
import sys

# Navigate to the parent directory of the project structure
project_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
src_dir = os.path.join(project_dir, 'src')
fig_dir = os.path.join(project_dir, 'fig')
data_dir = os.path.join(project_dir, 'data')
log_dir = os.path.join(project_dir, 'log')
os.makedirs(fig_dir, exist_ok=True)

# Add the src directory to sys.path
sys.path.append(src_dir)
import matplotlib.pyplot as plt
import numpy as np

import mech.full_DPSGD as DPSGDModule
from analysis.tradeoff_Gaussian import Gaussian_curve

# %%
model_name = 'convnet_balanced'
database_size = 1000
epochs = 20
internal_result_path_dir = "/scratch/bell/wei402/fdp-estimation/results"

internal_result_path_prefix = os.path.join(internal_result_path_dir, model_name+'_'+str(database_size)+'_'+str(epochs))


data_args = {
    "method": "default",
    "data_dir": data_dir,
    "internal_result_path": os.path.join(internal_result_path_prefix, 'train')
}

args = DPSGDModule.generate_params(data_args=data_args, log_dir=log_dir, model_name=model_name, database_size=database_size, epochs=epochs, auditing_approach="1d_logit")

estimator_logit = DPSGDModule.DPSGD_PTLREstimator(args)
output = estimator_logit.build(eta_max = 15)
# Extract alpha and beta for plotting
alpha_logit = output["alpha"]
beta_logit = output["beta"]
# Out:
# Files already downloaded and verified
# 05/18/2025 22:59:41:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/18/2025 22:59:41:INFO:Need to generate 1000 samples.
# 05/18/2025 22:59:41:INFO:Found 1000 existing model pairs. Need to generate 0 more.
# Loading and projecting models with 1 workers:
# Generating samples:   0%|          | 0/20 [00:00<?, ?it/s]05/18/2025 22:59:42:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# /home/wei402/Desktop/fdp-estimation/src/mech/full_DPSGD.py:337: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# Generating samples:   5%|▌         | 1/20 [00:03<01:12,  3.81s/it]05/18/2025 22:59:46:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  10%|█         | 2/20 [00:07<01:03,  3.53s/it]05/18/2025 22:59:49:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  15%|█▌        | 3/20 [00:10<00:54,  3.23s/it]05/18/2025 22:59:52:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  20%|██        | 4/20 [00:12<00:48,  3.06s/it]05/18/2025 22:59:55:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  25%|██▌       | 5/20 [00:15<00:42,  2.86s/it]05/18/2025 22:59:58:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  30%|███       | 6/20 [00:17<00:38,  2.77s/it]05/18/2025 23:00:00:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  35%|███▌      | 7/20 [00:20<00:35,  2.70s/it]05/18/2025 23:00:03:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  40%|████      | 8/20 [00:22<00:31,  2.62s/it]05/18/2025 23:00:05:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  45%|████▌     | 9/20 [00:25<00:28,  2.56s/it]05/18/2025 23:00:08:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  50%|█████     | 10/20 [00:27<00:25,  2.51s/it]05/18/2025 23:00:10:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  55%|█████▌    | 11/20 [00:30<00:22,  2.45s/it]05/18/2025 23:00:12:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  60%|██████    | 12/20 [00:32<00:19,  2.40s/it]05/18/2025 23:00:15:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  65%|██████▌   | 13/20 [00:34<00:17,  2.43s/it]05/18/2025 23:00:17:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  70%|███████   | 14/20 [00:37<00:14,  2.42s/it]05/18/2025 23:00:20:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  75%|███████▌  | 15/20 [00:39<00:12,  2.42s/it]05/18/2025 23:00:22:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  80%|████████  | 16/20 [00:41<00:09,  2.37s/it]05/18/2025 23:00:24:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  85%|████████▌ | 17/20 [00:44<00:07,  2.38s/it]05/18/2025 23:00:27:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  90%|█████████ | 18/20 [00:46<00:04,  2.34s/it]05/18/2025 23:00:29:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  95%|█████████▌| 19/20 [00:48<00:02,  2.36s/it]05/18/2025 23:00:31:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples: 100%|██████████| 20/20 [00:51<00:00,  2.56s/it]
# Loading and projecting models with 1 workers:
# Generating samples:   0%|          | 0/20 [00:00<?, ?it/s]05/18/2025 23:00:35:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# /home/wei402/Desktop/fdp-estimation/src/mech/full_DPSGD.py:337: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# Generating samples:   5%|▌         | 1/20 [00:03<01:08,  3.61s/it]05/18/2025 23:00:39:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  10%|█         | 2/20 [00:06<01:01,  3.43s/it]05/18/2025 23:00:42:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  15%|█▌        | 3/20 [00:09<00:51,  3.04s/it]05/18/2025 23:00:44:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  20%|██        | 4/20 [00:11<00:44,  2.78s/it]05/18/2025 23:00:47:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  25%|██▌       | 5/20 [00:14<00:40,  2.70s/it]05/18/2025 23:00:49:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  30%|███       | 6/20 [00:16<00:35,  2.57s/it]05/18/2025 23:00:52:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  35%|███▌      | 7/20 [00:19<00:32,  2.51s/it]05/18/2025 23:00:54:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  40%|████      | 8/20 [00:21<00:29,  2.48s/it]05/18/2025 23:00:57:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  45%|████▌     | 9/20 [00:23<00:27,  2.47s/it]05/18/2025 23:00:59:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  50%|█████     | 10/20 [00:26<00:24,  2.41s/it]05/18/2025 23:01:01:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  55%|█████▌    | 11/20 [00:28<00:21,  2.41s/it]05/18/2025 23:01:04:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  60%|██████    | 12/20 [00:31<00:19,  2.42s/it]05/18/2025 23:01:06:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  65%|██████▌   | 13/20 [00:33<00:16,  2.41s/it]05/18/2025 23:01:08:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  70%|███████   | 14/20 [00:35<00:14,  2.42s/it]05/18/2025 23:01:11:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  75%|███████▌  | 15/20 [00:38<00:11,  2.37s/it]05/18/2025 23:01:13:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  80%|████████  | 16/20 [00:40<00:09,  2.39s/it]05/18/2025 23:01:16:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  85%|████████▌ | 17/20 [00:42<00:07,  2.37s/it]05/18/2025 23:01:18:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  90%|█████████ | 18/20 [00:45<00:04,  2.39s/it]05/18/2025 23:01:20:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  95%|█████████▌| 19/20 [00:47<00:02,  2.35s/it]05/18/2025 23:01:23:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples: 100%|██████████| 20/20 [00:49<00:00,  2.50s/it]

# %%
args = DPSGDModule.generate_params(data_args=data_args, log_dir=log_dir, model_name=model_name, database_size=database_size, epochs=epochs, auditing_approach="1d_cross_entropy")

estimator_logit = DPSGDModule.DPSGD_PTLREstimator(args)
output = estimator_logit.build(eta_max = 15)
# Extract alpha and beta for plotting
alpha_cross_entropy = output["alpha"]
beta_cross_entropy = output["beta"]
# Out:
# Files already downloaded and verified
# 05/18/2025 23:01:54:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/18/2025 23:01:54:INFO:Need to generate 1000 samples.
# 05/18/2025 23:01:54:INFO:Found 1000 existing model pairs. Need to generate 0 more.
# Loading and projecting models with 1 workers:
# Generating samples:   5%|▌         | 1/20 [00:00<00:17,  1.11it/s]05/18/2025 23:01:56:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# /home/wei402/Desktop/fdp-estimation/src/mech/full_DPSGD.py:337: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# 05/18/2025 23:01:58:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  10%|█         | 2/20 [00:02<00:22,  1.27s/it]05/18/2025 23:01:59:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  15%|█▌        | 3/20 [00:04<00:29,  1.73s/it]05/18/2025 23:02:01:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  20%|██        | 4/20 [00:06<00:26,  1.66s/it]05/18/2025 23:02:02:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  30%|███       | 6/20 [00:08<00:20,  1.46s/it]05/18/2025 23:02:04:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/18/2025 23:02:05:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  35%|███▌      | 7/20 [00:10<00:19,  1.51s/it]05/18/2025 23:02:07:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  40%|████      | 8/20 [00:12<00:21,  1.78s/it]05/18/2025 23:02:09:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  45%|████▌     | 9/20 [00:14<00:18,  1.73s/it]05/18/2025 23:02:10:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  55%|█████▌    | 11/20 [00:16<00:13,  1.52s/it]05/18/2025 23:02:12:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  60%|██████    | 12/20 [00:18<00:12,  1.55s/it]05/18/2025 23:02:14:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  65%|██████▌   | 13/20 [00:20<00:11,  1.57s/it]05/18/2025 23:02:15:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/18/2025 23:02:17:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  70%|███████   | 14/20 [00:21<00:09,  1.60s/it]05/18/2025 23:02:18:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  75%|███████▌  | 15/20 [00:23<00:07,  1.59s/it]05/18/2025 23:02:20:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  80%|████████  | 16/20 [00:24<00:06,  1.60s/it]05/18/2025 23:02:22:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  85%|████████▌ | 17/20 [00:26<00:04,  1.65s/it]05/18/2025 23:02:23:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  90%|█████████ | 18/20 [00:28<00:03,  1.64s/it]05/18/2025 23:02:25:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  95%|█████████▌| 19/20 [00:29<00:01,  1.65s/it]05/18/2025 23:02:27:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples: 100%|██████████| 20/20 [00:31<00:00,  1.56s/it]
# Loading and projecting models with 1 workers:
# Generating samples:   5%|▌         | 1/20 [00:00<00:16,  1.14it/s]05/18/2025 23:02:29:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# /home/wei402/Desktop/fdp-estimation/src/mech/full_DPSGD.py:337: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# 05/18/2025 23:02:30:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  10%|█         | 2/20 [00:03<00:30,  1.71s/it]05/18/2025 23:02:32:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  15%|█▌        | 3/20 [00:04<00:22,  1.34s/it]05/18/2025 23:02:33:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  20%|██        | 4/20 [00:06<00:27,  1.74s/it]05/18/2025 23:02:35:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  25%|██▌       | 5/20 [00:07<00:21,  1.43s/it]05/18/2025 23:02:37:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  30%|███       | 6/20 [00:08<00:20,  1.49s/it]05/18/2025 23:02:38:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  35%|███▌      | 7/20 [00:10<00:20,  1.55s/it]05/18/2025 23:02:40:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  40%|████      | 8/20 [00:12<00:21,  1.81s/it]05/18/2025 23:02:42:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  45%|████▌     | 9/20 [00:13<00:16,  1.52s/it]05/18/2025 23:02:43:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  50%|█████     | 10/20 [00:15<00:15,  1.55s/it]05/18/2025 23:02:45:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  60%|██████    | 12/20 [00:18<00:12,  1.61s/it]05/18/2025 23:02:47:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/18/2025 23:02:48:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  65%|██████▌   | 13/20 [00:20<00:11,  1.62s/it]05/18/2025 23:02:50:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  75%|███████▌  | 15/20 [00:23<00:07,  1.56s/it]05/18/2025 23:02:51:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/18/2025 23:02:53:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  80%|████████  | 16/20 [00:25<00:06,  1.60s/it]05/18/2025 23:02:55:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  85%|████████▌ | 17/20 [00:27<00:04,  1.61s/it]05/18/2025 23:02:56:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  90%|█████████ | 18/20 [00:28<00:03,  1.61s/it]05/18/2025 23:02:58:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  95%|█████████▌| 19/20 [00:30<00:01,  1.61s/it]05/18/2025 23:03:00:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples: 100%|██████████| 20/20 [00:31<00:00,  1.57s/it]

# %%
file_name = os.path.join(fig_dir, f"estimation_{model_name}_{database_size}.png")
# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(alpha_logit, beta_logit, color="firebrick", s=10, label="KDE Estimator (logit)")
plt.scatter(alpha_cross_entropy, beta_cross_entropy, color="green", s=10, label="KDE Estimator (cross_entropy)")
alpha_values = np.linspace(0, 1, 1000)
plt.plot(alpha_values, Gaussian_curve(alpha_values, mean_difference = 0.3), color="deepskyblue", linewidth=1.5, label="Gaussian Curve (mu=0.3)")
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.xlabel("Alpha")
plt.ylabel("Beta")
plt.title("KDE Estimator vs Gaussian Curve")
plt.legend()
plt.grid()

# Save the plot
plt.savefig(file_name, bbox_inches = 'tight', dpi = 300);
plt.show()
