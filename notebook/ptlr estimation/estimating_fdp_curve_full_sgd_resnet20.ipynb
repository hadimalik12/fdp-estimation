# %%
import os
import sys

# Navigate to the parent directory of the project structure
project_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
src_dir = os.path.join(project_dir, 'src')
fig_dir = os.path.join(project_dir, 'fig')
data_dir = os.path.join(project_dir, 'data')
log_dir = os.path.join(project_dir, 'log')
os.makedirs(fig_dir, exist_ok=True)

# Add the src directory to sys.path
sys.path.append(src_dir)
import matplotlib.pyplot as plt
import numpy as np

import mech.full_DPSGD as DPSGDModule
from analysis.tradeoff_Gaussian import Gaussian_curve

# %%
model_name = 'resnet20'
database_size = 1000
epochs = 20
internal_result_path_dir = "/scratch/bell/wei402/fdp-estimation/results"

internal_result_path_prefix = os.path.join(internal_result_path_dir, model_name+'_'+str(database_size)+'_'+str(epochs))


data_args = {
    "method": "default",
    "data_dir": data_dir,
    "internal_result_path": os.path.join(internal_result_path_prefix, 'train')
}

args = DPSGDModule.generate_params(data_args=data_args, log_dir=log_dir, model_name=model_name, database_size=database_size, epochs=epochs, auditing_approach="1d_logit")

estimator_logit = DPSGDModule.DPSGD_PTLREstimator(args)
output = estimator_logit.build(eta_max = 15)
# Extract alpha and beta for plotting
alpha_logit = output["alpha"]
beta_logit = output["beta"]
# Out:
# Files already downloaded and verified
# 05/19/2025 08:43:25:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/19/2025 08:43:25:INFO:Need to generate 1000 samples.
# 05/19/2025 08:43:25:INFO:Found 1000 existing model pairs. Need to generate 0 more.
# Loading and projecting models with 1 workers:
# Generating samples:   0%|          | 0/20 [00:00<?, ?it/s]05/19/2025 08:43:27:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# /home/wei402/Desktop/fdp-estimation/src/mech/full_DPSGD.py:342: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# Generating samples:   5%|▌         | 1/20 [00:04<01:18,  4.12s/it]05/19/2025 08:43:31:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  10%|█         | 2/20 [00:07<01:06,  3.71s/it]05/19/2025 08:43:34:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  15%|█▌        | 3/20 [00:10<00:58,  3.46s/it]05/19/2025 08:43:37:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  20%|██        | 4/20 [00:13<00:50,  3.17s/it]05/19/2025 08:43:40:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  25%|██▌       | 5/20 [00:16<00:45,  3.01s/it]05/19/2025 08:43:43:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  30%|███       | 6/20 [00:18<00:40,  2.87s/it]05/19/2025 08:43:46:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  35%|███▌      | 7/20 [00:21<00:35,  2.72s/it]05/19/2025 08:43:48:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  40%|████      | 8/20 [00:23<00:31,  2.61s/it]05/19/2025 08:43:50:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  45%|████▌     | 9/20 [00:26<00:28,  2.63s/it]05/19/2025 08:43:53:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  50%|█████     | 10/20 [00:28<00:26,  2.67s/it]05/19/2025 08:43:56:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  55%|█████▌    | 11/20 [00:31<00:23,  2.65s/it]05/19/2025 08:43:58:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  60%|██████    | 12/20 [00:33<00:20,  2.56s/it]05/19/2025 08:44:01:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  65%|██████▌   | 13/20 [00:36<00:17,  2.51s/it]05/19/2025 08:44:03:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  70%|███████   | 14/20 [00:38<00:15,  2.53s/it]05/19/2025 08:44:06:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  75%|███████▌  | 15/20 [00:41<00:12,  2.53s/it]05/19/2025 08:44:08:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  80%|████████  | 16/20 [00:43<00:09,  2.46s/it]05/19/2025 08:44:11:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  85%|████████▌ | 17/20 [00:46<00:07,  2.57s/it]05/19/2025 08:44:13:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  90%|█████████ | 18/20 [00:48<00:05,  2.51s/it]05/19/2025 08:44:16:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  95%|█████████▌| 19/20 [00:51<00:02,  2.45s/it]05/19/2025 08:44:18:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples: 100%|██████████| 20/20 [00:53<00:00,  2.67s/it]
# Loading and projecting models with 1 workers:
# Generating samples:   0%|          | 0/20 [00:00<?, ?it/s]05/19/2025 08:44:22:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# /home/wei402/Desktop/fdp-estimation/src/mech/full_DPSGD.py:342: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# Generating samples:   5%|▌         | 1/20 [00:03<01:05,  3.46s/it]05/19/2025 08:44:25:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  10%|█         | 2/20 [00:06<00:57,  3.20s/it]05/19/2025 08:44:28:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  15%|█▌        | 3/20 [00:08<00:48,  2.88s/it]05/19/2025 08:44:31:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  20%|██        | 4/20 [00:11<00:43,  2.75s/it]05/19/2025 08:44:33:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  25%|██▌       | 5/20 [00:13<00:39,  2.60s/it]05/19/2025 08:44:36:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  30%|███       | 6/20 [00:16<00:35,  2.52s/it]05/19/2025 08:44:38:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  35%|███▌      | 7/20 [00:18<00:32,  2.50s/it]05/19/2025 08:44:40:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  40%|████      | 8/20 [00:20<00:29,  2.43s/it]05/19/2025 08:44:43:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  45%|████▌     | 9/20 [00:23<00:25,  2.35s/it]05/19/2025 08:44:45:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  50%|█████     | 10/20 [00:25<00:24,  2.41s/it]05/19/2025 08:44:47:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  55%|█████▌    | 11/20 [00:28<00:22,  2.45s/it]05/19/2025 08:44:50:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/19/2025 08:44:52:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  65%|██████▌   | 13/20 [00:32<00:16,  2.33s/it]05/19/2025 08:44:55:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  70%|███████   | 14/20 [00:35<00:14,  2.38s/it]05/19/2025 08:44:57:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  75%|███████▌  | 15/20 [00:37<00:11,  2.34s/it]05/19/2025 08:44:59:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  80%|████████  | 16/20 [00:39<00:09,  2.26s/it]05/19/2025 08:45:01:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  85%|████████▌ | 17/20 [00:41<00:06,  2.23s/it]05/19/2025 08:45:04:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  90%|█████████ | 18/20 [00:44<00:04,  2.31s/it]05/19/2025 08:45:06:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  95%|█████████▌| 19/20 [00:46<00:02,  2.24s/it]05/19/2025 08:45:08:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples: 100%|██████████| 20/20 [00:48<00:00,  2.43s/it]

# %%
args = DPSGDModule.generate_params(data_args=data_args, log_dir=log_dir, model_name=model_name, database_size=database_size, epochs=epochs, auditing_approach="1d_cross_entropy")

estimator_logit = DPSGDModule.DPSGD_PTLREstimator(args)
output = estimator_logit.build(eta_max = 15)
# Extract alpha and beta for plotting
alpha_cross_entropy = output["alpha"]
beta_cross_entropy = output["beta"]
# Out:
# Files already downloaded and verified
# 05/19/2025 09:03:16:INFO:Initialized resnet20_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/19/2025 09:03:16:INFO:Found 1000 samples in /scratch/bell/wei402/fdp-estimation/results/resnet20_1000_20/train/samples_folder/samples_resnet20. Skipping generation.

# %%
file_name = os.path.join(fig_dir, f"estimation_{model_name}_{database_size}.png")
# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(alpha_logit, beta_logit, color="firebrick", s=10, label="KDE Estimator (logit)")
plt.scatter(alpha_cross_entropy, beta_cross_entropy, color="green", s=10, label="KDE Estimator (cross_entropy)")
alpha_values = np.linspace(0, 1, 1000)
plt.plot(alpha_values, Gaussian_curve(alpha_values, mean_difference = 0.3), color="deepskyblue", linewidth=1.5, label="Gaussian Curve (mu=0.3)")
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.xlabel("Alpha")
plt.ylabel("Beta")
plt.title("KDE Estimator vs Gaussian Curve")
plt.legend()
plt.grid()

# Save the plot
# plt.savefig(file_name, bbox_inches = 'tight', dpi = 300);
plt.show()
