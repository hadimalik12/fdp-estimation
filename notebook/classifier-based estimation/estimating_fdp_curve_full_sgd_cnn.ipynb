# %%
import os
import sys

# Navigate to the parent directory of the project structure
project_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
src_dir = os.path.join(project_dir, 'src')
fig_dir = os.path.join(project_dir, 'fig')
data_dir = os.path.join(project_dir, 'data')
log_dir = os.path.join(project_dir, 'log')
os.makedirs(fig_dir, exist_ok=True)

# Add the src directory to sys.path
sys.path.append(src_dir)
import matplotlib.pyplot as plt
import numpy as np

import mech.full_DPSGD as DPSGDModule
from analysis.tradeoff_Gaussian import Gaussian_curve

# %%
model_name = 'convnet_balanced'
database_size = 1000
epochs = 20
internal_result_path = "/scratch/bell/wei402/fdp-estimation/results"


data_args = {
    "method": "default",
    "data_dir": data_dir,
    "internal_result_path": internal_result_path
}

args = DPSGDModule.generate_params(data_args=data_args, log_dir=log_dir, model_name=model_name, database_size=database_size, epochs=epochs, auditing_approach="1d_KLDivLoss", num_test_samples=1000)

eta_values = np.linspace(0.01, 15, 100)
estimator = DPSGDModule.DPSGD_Estimator(args)
output = estimator.build(eta_values, nworkers=50)
# Extract alpha and beta for plotting
alpha_values_estimate = output["alpha"]
beta_values_estimate = output["beta"]
# Out:
# Files already downloaded and verified
# 05/19/2025 18:20:23:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/19/2025 18:20:23:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# 05/19/2025 18:20:23:INFO:Need to generate 1000 samples.
# 05/19/2025 18:20:23:INFO:Found 1010 existing model pairs. Need to generate 0 more.
# Loading and projecting models with 1 workers:
# Generating samples:   0%|          | 0/20 [00:00<?, ?it/s]05/19/2025 18:20:24:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# /home/wei402/Desktop/fdp-estimation/src/mech/full_DPSGD.py:365: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# Generating samples:   5%|▌         | 1/20 [00:01<00:30,  1.59s/it]05/19/2025 18:20:26:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  10%|█         | 2/20 [00:04<00:40,  2.27s/it]05/19/2025 18:20:29:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  15%|█▌        | 3/20 [00:06<00:39,  2.32s/it]05/19/2025 18:20:31:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  20%|██        | 4/20 [00:09<00:38,  2.42s/it]05/19/2025 18:20:34:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  25%|██▌       | 5/20 [00:11<00:36,  2.43s/it]05/19/2025 18:20:36:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  30%|███       | 6/20 [00:14<00:33,  2.41s/it]05/19/2025 18:20:38:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  35%|███▌      | 7/20 [00:16<00:29,  2.29s/it]05/19/2025 18:20:40:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  40%|████      | 8/20 [00:18<00:26,  2.23s/it]05/19/2025 18:20:43:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  45%|████▌     | 9/20 [00:20<00:25,  2.27s/it]05/19/2025 18:20:45:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  50%|█████     | 10/20 [00:22<00:22,  2.25s/it]05/19/2025 18:20:47:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  55%|█████▌    | 11/20 [00:24<00:19,  2.20s/it]05/19/2025 18:20:49:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  60%|██████    | 12/20 [00:27<00:17,  2.19s/it]05/19/2025 18:20:51:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  65%|██████▌   | 13/20 [00:29<00:15,  2.24s/it]05/19/2025 18:20:54:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  70%|███████   | 14/20 [00:31<00:13,  2.20s/it]05/19/2025 18:20:56:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  75%|███████▌  | 15/20 [00:33<00:10,  2.13s/it]05/19/2025 18:20:58:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  80%|████████  | 16/20 [00:35<00:08,  2.11s/it]05/19/2025 18:21:00:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  85%|████████▌ | 17/20 [00:37<00:06,  2.20s/it]05/19/2025 18:21:02:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  90%|█████████ | 18/20 [00:40<00:04,  2.16s/it]05/19/2025 18:21:04:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  95%|█████████▌| 19/20 [00:41<00:02,  2.07s/it]05/19/2025 18:21:06:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples: 100%|██████████| 20/20 [00:43<00:00,  2.19s/it]
# Loading and projecting models with 1 workers:
# Generating samples:   0%|          | 0/20 [00:00<?, ?it/s]05/19/2025 18:21:10:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# /home/wei402/Desktop/fdp-estimation/src/mech/full_DPSGD.py:365: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# Generating samples:   5%|▌         | 1/20 [00:02<00:50,  2.64s/it]05/19/2025 18:21:12:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  10%|█         | 2/20 [00:04<00:43,  2.39s/it]05/19/2025 18:21:15:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  15%|█▌        | 3/20 [00:06<00:38,  2.25s/it]05/19/2025 18:21:17:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  20%|██        | 4/20 [00:09<00:36,  2.28s/it]05/19/2025 18:21:19:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  25%|██▌       | 5/20 [00:11<00:34,  2.27s/it]05/19/2025 18:21:21:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  30%|███       | 6/20 [00:13<00:30,  2.19s/it]05/19/2025 18:21:23:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  35%|███▌      | 7/20 [00:15<00:28,  2.20s/it]05/19/2025 18:21:25:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  40%|████      | 8/20 [00:18<00:27,  2.26s/it]05/19/2025 18:21:28:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  45%|████▌     | 9/20 [00:20<00:24,  2.19s/it]05/19/2025 18:21:30:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  50%|█████     | 10/20 [00:22<00:21,  2.19s/it]05/19/2025 18:21:32:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  55%|█████▌    | 11/20 [00:24<00:19,  2.13s/it]05/19/2025 18:21:34:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  60%|██████    | 12/20 [00:26<00:16,  2.10s/it]05/19/2025 18:21:36:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  65%|██████▌   | 13/20 [00:28<00:14,  2.02s/it]05/19/2025 18:21:38:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  70%|███████   | 14/20 [00:30<00:11,  1.98s/it]05/19/2025 18:21:40:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  75%|███████▌  | 15/20 [00:32<00:10,  2.01s/it]05/19/2025 18:21:42:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  80%|████████  | 16/20 [00:34<00:08,  2.03s/it]05/19/2025 18:21:44:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  85%|████████▌ | 17/20 [00:36<00:06,  2.02s/it]05/19/2025 18:21:46:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  90%|█████████ | 18/20 [00:38<00:04,  2.01s/it]05/19/2025 18:21:48:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples:  95%|█████████▌| 19/20 [00:40<00:02,  2.06s/it]05/19/2025 18:21:50:INFO:Initialized convnet_balanced_DPSGDSampler with parameters: batch_size=512, epochs=20, lr=0.10, sigma=1.00, max_grad_norm=1.00, device=cpu
# Generating samples: 100%|██████████| 20/20 [00:42<00:00,  2.12s/it]
# 05/19/2025 18:21:52:INFO:Found 1000 samples in /scratch/bell/wei402/fdp-estimation/results/train/convnet_balanced_1000_20/samples_folder. Skipping generation.

# %%
file_name = os.path.join(fig_dir, f"KNN_estimation_{model_name}_{database_size}.png")
# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(alpha_values_estimate, beta_values_estimate, color="red", s=10, label="KNN Estimator")
alpha_values = np.linspace(0, 1, 1000)
plt.plot(alpha_values, Gaussian_curve(alpha_values, mean_difference = 0.3), color="deepskyblue", linewidth=1.5, label="Gaussian Curve (mu=0.3)")
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.xlabel("Alpha")
plt.ylabel("Beta")
plt.title("KNN Estimator vs Gaussian Curve")
plt.legend()
plt.grid()

# Save the plot
plt.savefig(file_name, bbox_inches = 'tight', dpi = 300);
plt.show()
