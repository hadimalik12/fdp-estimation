# %%
import numpy as np
from scipy.special import erf
import os
import sys
import time
import logging
import matplotlib.pyplot as plt

# Navigate to the parent directory of the project structure
project_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
src_dir = os.path.join(project_dir, 'src')

# Add the src directory to sys.path
sys.path.append(src_dir)

from analysis.tradeoff_Gaussian import Gaussian_compute_tradeoff_curve
from analysis.tradeoff_Laplace import Laplace_compute_tradeoff_curve
from analysis.accuracy_analysis import acc_evaluate

from mech.GaussianDist import *
from classifier.kNN import train_kNN_model

# %%
num_train_samples = 10000
num_test_samples = 100000
estimator_params = generate_params(num_train_samples = num_train_samples, num_test_samples = num_test_samples)
eta_array = np.linspace(0.01, 5, 100)
nworkers = 50

log_dir = os.path.join(project_dir, 'log')

# %%
logfile_path = os.path.join(log_dir, 'tradeoff-kNN-Gaussian.log')
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(message)s",
    handlers=[
        logging.FileHandler(logfile_path)
        # logging.StreamHandler()
    ]
)

# %%
for num_train_samples in [10**4, 10**5, 10**6, 10**7, 10**8]:
    estimator_params = generate_params(num_train_samples = num_train_samples, num_test_samples = num_test_samples)
    
    acc_evaluate(
        thm_tradeoff_func = Gaussian_compute_tradeoff_curve, 
        estimator_cls = GaussianDistEstimator, 
        estimator_params = estimator_params, 
        eta_array = eta_array, 
        num_train_samples = num_train_samples, 
        logfile_path = logfile_path, 
        nworkers=nworkers)
# Out:
# Process ForkPoolWorker-251:
# Process ForkPoolWorker-241:
# Process ForkPoolWorker-233:
# Process ForkPoolWorker-239:
# Process ForkPoolWorker-288:
# Process ForkPoolWorker-284:
# Process ForkPoolWorker-255:
# Process ForkPoolWorker-289:
# Process ForkPoolWorker-271:
# Process ForkPoolWorker-253:
# Process ForkPoolWorker-256:
# Process ForkPoolWorker-269:
# Process ForkPoolWorker-278:
# Process ForkPoolWorker-252:
# Process ForkPoolWorker-265:
# Process ForkPoolWorker-264:
# Process ForkPoolWorker-259:
# Process ForkPoolWorker-260:
# Process ForkPoolWorker-267:
# Process ForkPoolWorker-238:
# Process ForkPoolWorker-261:
# Process ForkPoolWorker-279:
# Process ForkPoolWorker-285:
# Process ForkPoolWorker-292:
# Process ForkPoolWorker-257:
# Process ForkPoolWorker-274:
# Process ForkPoolWorker-258:
# Process ForkPoolWorker-273:
# Process ForkPoolWorker-293:
# Process ForkPoolWorker-272:
# Process ForkPoolWorker-282:
# Process ForkPoolWorker-291:
# Process ForkPoolWorker-263:
# Process ForkPoolWorker-276:
# Process ForkPoolWorker-275:
# Process ForkPoolWorker-290:
# Process ForkPoolWorker-254:
# Process ForkPoolWorker-240:
# Process ForkPoolWorker-268:
# Process ForkPoolWorker-287:
# Process ForkPoolWorker-277:
# Process ForkPoolWorker-280:
# Process ForkPoolWorker-286:
# Process ForkPoolWorker-283:
# Process ForkPoolWorker-262:
# Process ForkPoolWorker-294:
# Process ForkPoolWorker-270:
# Process ForkPoolWorker-266:
# Process ForkPoolWorker-281:
# Process ForkPoolWorker-250:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/estimator/basic.py", line 141, in compute_tradeoff_point
#     alpha = 1 - model.score(test_samples['X'][:num_test_samples], test_samples['y'][:num_test_samples])
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/estimator/basic.py", line 141, in compute_tradeoff_point
#     alpha = 1 - model.score(test_samples['X'][:num_test_samples], test_samples['y'][:num_test_samples])
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/estimator/basic.py", line 141, in compute_tradeoff_point
#     alpha = 1 - model.score(test_samples['X'][:num_test_samples], test_samples['y'][:num_test_samples])
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/estimator/basic.py", line 141, in compute_tradeoff_point
#     alpha = 1 - model.score(test_samples['X'][:num_test_samples], test_samples['y'][:num_test_samples])
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/estimator/basic.py", line 141, in compute_tradeoff_point
#     alpha = 1 - model.score(test_samples['X'][:num_test_samples], test_samples['y'][:num_test_samples])
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/estimator/basic.py", line 141, in compute_tradeoff_point
#     alpha = 1 - model.score(test_samples['X'][:num_test_samples], test_samples['y'][:num_test_samples])
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 75, in score
#     return (self.predict(test_features) == test_labels).mean()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 75, in score
#     return (self.predict(test_features) == test_labels).mean()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 75, in score
#     return (self.predict(test_features) == test_labels).mean()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 75, in score
#     return (self.predict(test_features) == test_labels).mean()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 75, in score
#     return (self.predict(test_features) == test_labels).mean()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 61, in predict
#     if np.abs(self.index[tail_p] - value) >= np.abs(self.index[head_p] - value):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 60, in predict
#     while head_p < len(self.index) - 1:
#                    ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 60, in predict
#     while head_p < len(self.index) - 1:
#                    ^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 75, in score
#     return (self.predict(test_features) == test_labels).mean()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 61, in predict
#     if np.abs(self.index[tail_p] - value) >= np.abs(self.index[head_p] - value):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 61, in predict
#     if np.abs(self.index[tail_p] - value) >= np.abs(self.index[head_p] - value):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wei402/Desktop/fdp-estimation/src/classifier/kNN.py", line 60, in predict
#     while head_p < len(self.index) - 1:
#                    ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 for num_train_samples in [10**4, 10**5, 10**6, 10**7, 10**8]:
#       2     estimator_params = generate_params(num_train_samples = num_train_samples, num_test_samples = num_test_samples)
# ----> 4     acc_evaluate(
#       5         thm_tradeoff_func = Gaussian_compute_tradeoff_curve,
#       6         estimator_cls = GaussianDistEstimator,
#       7         estimator_params = estimator_params,
#       8         eta_array = eta_array,
#       9         num_train_samples = num_train_samples,
#      10         logfile_path = logfile_path,
#      11         nworkers=nworkers)
#
# File ~/Desktop/fdp-estimation/src/analysis/accuracy_analysis.py:20, in acc_evaluate(thm_tradeoff_func, estimator_cls, estimator_params, eta_array, num_train_samples, num_test_samples, classifier_args, logfile_path, nworkers)
#      18 # Function logic here...
#      19 estimator = estimator_cls(estimator_params)
# ---> 20 output = estimator.build(eta = eta_array, nworkers=nworkers)
#      21 alpha_values_estimate = output["alpha"]
#      22 beta_values_estimate = output["beta"]
#
# File ~/Desktop/fdp-estimation/src/estimator/basic.py:95, in _GeneralNaiveEstimator.build(self, eta, nworkers, classifier_args)
#      93 eta_array = _ensure_np_array(eta)
#      94 input_list = np.array_split(eta_array, min(nworkers, len(eta_array)))
# ---> 95 results_list = pool.map(partial_compute_tradeoff_point, input_list)
#      97 for result in results_list:
#      98     alpha_array.append(result[0])
#
# File /apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /apps/cent7/anaconda/2024.02/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /apps/cent7/anaconda/2024.02/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /apps/cent7/anaconda/2024.02/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:
